# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('dataset/data.csv')
df.sample(9)
# Out:
#                    user_id         username  age  status sex orientation  \
# 744       fffe370034003500      Joe Sanchez   41  single   m    straight
# 1334  fffe3100330033003500      Mary Torres   52  single   f    straight
# 1392  fffe3100330039003300      Luis Gentry   55  single   m    straight
# 792       fffe370039003300     Ivory Hanson   22  single   m    straight
# 292       fffe320039003300  Cruz Rutherford   29  single   m    straight
# 1989  fffe3100390039003000      Scott Grady   19  single   m    straight
# 893       fffe380039003400    Stuart Snyder   27  single   m    straight
# 513       fffe350031003400       Katy Evans   27  single   f    straight
# 244       fffe320034003500      Imogene May   40  single   f    straight
#
#           drinks  drugs  height                           job  ...     smokes  \
# 744     socially  never    71.0  science / tech / engineering  ...  sometimes
# 1334      rarely  never    63.0          education / academia  ...         no
# ...

# %%
for col in df.columns:
    print("***************************")
    print(col)
    print(df[col].value_counts())
# Out:
# ***************************
# user_id
# fffe3100330032003400    1
# fffe340035003300        1
# fffe3100370037003100    1
# fffe370039003700        1
# fffe3100300035003000    1
#                        ..
# fffe330032003400        1
# fffe390031003000        1
# fffe380036003500        1
# fffe37003100            1
# fffe330037003700        1
# Name: user_id, Length: 2001, dtype: int64
# ***************************
# username
# Michael Johnson    2
# Daniel Harris      2
# Mary Perez         2
# James Davidson     2
# Mary Taylor        2
#                   ..
# Delores Davis      1
# Frances Sparks     1
# Daniel Davis       1
# Agnes Garland      1
# Justin Wright      1
# Name: username, Length: 1995, dtype: int64
# ***************************
# age
# 28    116
# 26    116
# 27    115
# 24    107
# 31    106
# 30     98
# 29     95
# 22     93
# 23     79
# 25     79
# 33     71
# 32     69
# 21     57
# 34     49
# 37     46
# 35     43
# 42     42
# 38     41
# 39     40
# ...

# %% [markdown]
# ## Inference
# **Thoughts about different columns:**
#
#     1.username:There are some duplicate names but they have differnt attributes so basically different person
#     2.age:Age is widely spread and is an integer so basically a bin method can be used for further study on this columns
#     3.status : a cat variable would look to make it label or hot encode after research but available and single has to be    seen how they are different categories
#     4.sex:males dominate in the dating app ,a categorical var
#     5.orientation :a categorical var
#     6.drinks:a categorical var
#     7.drugs:a categorcial var
#     8.height: a interger variable in a range
#     9.job:lot of categories can be used label encode
#     10.location : these locations can be used to see where one is located and how close they are located
#     11.pets : feature can be taken out from this and dogs and cats can be taken out as feature instead.
#     12.smokes: a cat var can be used as it is
#     13.languages: features can be derived from this and fluently,poorly,okay can be given scores
#     14.new_langauges: a cat var
#     15.body_profile : cat var but the body_profile for some profile looks the same instead we can make the body_prile more small and use fit and unfit as criteria.
#     16.Education Level : a cat var
#     17.dropped_out : a binary var
#     18.bio : it would require NLP to pull out features
#     19.interest and other_interesets : it is cat var
#     20.location_preference : it is a cat var and can be used along with the location given

# %% [markdown]
# ## Age

# %%
b = np.array(range(18,70,3))
plt.figure(figsize=(20,5))
plt.grid(axis='y', alpha=0.75)
n,bins,patches=plt.hist(df.age,bins=b,rwidth=0.85)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Different Age Categories Using the Dating App')
plt.show()

# %%
for i in range(len(bins)-1):
    print(f"[{bins[i]}-{bins[i+1]}):{n[i]}")
# Out:
# [18-21):78.0
# [21-24):229.0
# [24-27):302.0
# [27-30):326.0
# [30-33):273.0
# [33-36):163.0
# [36-39):124.0
# [39-42):101.0
# [42-45):104.0
# [45-48):73.0
# [48-51):60.0
# [51-54):50.0
# [54-57):33.0
# [57-60):33.0
# [60-63):22.0
# [63-66):18.0
# [66-69):12.0

# %% [markdown]
# One can clearly see that the people in the age 21-33 are highly engaged in the app .

# %% [markdown]
# ## Status

# %%
p=sns.catplot(x='status',kind="count",data=df)

# %% [markdown]
# Its obvious that a lot of single status would be using the app

# %%
k=df.groupby(['status']).age.value_counts()

# %%
t=k.single
x=[]
y=[]
for i in sorted(t.keys()):
    x.append(i)
    y.append(t[i])

# %%
plt.figure(figsize=(20,5))
plt.bar(x,y,color='g')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Different Age Categories Using the Dating App who are single')
plt.show()

# %%
n=k['seeing someone']
x=[]
y=[]
for i in sorted(n.keys()):
    x.append(i)
    y.append(n[i])
plt.figure(figsize=(20,5))
plt.bar(x,y,color='y')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Different Age Categories Using the Dating App who are seeing someone')
plt.show()

# %%
s=k['married']
x=[]
y=[]
for i in sorted(s.keys()):
    x.append(i)
    y.append(s[i])
plt.figure(figsize=(20,5))
plt.bar(x,y,color='r')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Different Age Categories Using the Dating App who are married')
plt.show()

# %%
s=k['available']
x=[]
y=[]
for i in sorted(s.keys()):
    x.append(i)
    y.append(s[i])
plt.figure(figsize=(20,5))
plt.bar(x,y,color='blue')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Different Age Categories Using the Dating App who are available')
plt.show()

# %% [markdown]
# The plots clearly depict that lot of single status people are from younger generation

# %% [markdown]
# ## Sex

# %%
m=df.groupby('sex').status.value_counts()

# %%
m
# Out:
# sex  status
# f    single             802
#      available           29
#      seeing someone      24
#      married              7
# m    single            1065
#      available           37
#      seeing someone      30
#      married              7
# Name: status, dtype: int64

# %%
t=m.m.plot(kind='bar',title='Male',color='orange')

# %%
s=m.m.plot(kind='bar',title='Female',color='r')

# %% [markdown]
# It seems that both the Female and Male Single have active participation in the App

# %% [markdown]
# ## Orientation

# %%
p=sns.catplot(x='orientation',kind="count",data=df)

# %% [markdown]
# ## Height

# %%
df['height'].describe()
# Out:
# count    2001.000000
# mean       68.289855
# std         3.895246
# min        55.000000
# 25%        65.000000
# 50%        68.000000
# 75%        71.000000
# max        83.000000
# Name: height, dtype: float64

# %%
sns.set_theme(style="whitegrid")
ax = sns.violinplot(x=df["height"])

# %%
ax = sns.violinplot(x="sex", y="height", data=df)

# %% [markdown]
# Females are shorter in height than an average male

# %% [markdown]
# ## Location

# %%
import geopandas as gpd

from geotext import GeoText

from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

from shapely.geometry import Point, Polygon
import descartes

# %%
def str_to_city(text):
    ans = ""
    i=0
    while text[i]!=',':
        ans += text[i]
        i+=1
    return ans    
city = df['location'].apply(lambda x:str_to_city(x))

# %%
 
geolocator = Nominatim(timeout=100,user_agent="smy-application")
i=0
lat_lon = []
for cit in city[1841:]: 
    print(i)
    try:
        location = geolocator.geocode(cit)
        
        if location:
            print(location.latitude, location.longitude)
            lat_lon.append(location)
    except GeocoderTimedOut as e:
        print(f"Error: geocode failed on input {cit} with message {e}")
        lat_lon.append(location[i-1])
    i += 1
lat_lon
# Out:
# 0
# 37.8708393 -122.2728639
# 1
# 37.7790262 -122.4199061
# 2
# 37.8708393 -122.2728639
# 3
# 37.7249296 -122.1560768
# 4
# 37.8044557 -122.2713563
# 5
# 37.8044557 -122.2713563
# 6
# 37.9774476 -122.2949894
# 7
# 37.7790262 -122.4199061
# 8
# 37.7790262 -122.4199061
# 9
# 37.6904826 -122.4726708
# 10
# 37.8590272 -122.4854694
# 11
# 37.4863239 -122.232523
# 12
# 37.9020731 -122.0618702
# 13
# 37.8590272 -122.4854694
# 14
# 37.7790262 -122.4199061
# 15
# 37.71573685 -122.09063177147789
# 16
# 38.1040864 -122.2566367
# 17
# 37.3893889 -122.0832101
# 18
# 37.7790262 -122.4199061
# 19
# 37.8044557 -122.2713563
# 20
# 37.7790262 -122.4199061
# 21
# 37.7790262 -122.4199061
# 22
# 37.4863239 -122.232523
# 23
# 37.6535403 -122.4168664
# 24
# 37.8044557 -122.2713563
# 25
# 37.9735346 -122.5310874
# 26
# 37.9735346 -122.5310874
# 27
# 37.8044557 -122.2713563
# 28
# 37.4443293 -122.1598465
# 29
# 37.8314089 -122.2865266
# 30
# 37.9254806 -122.5274755
# 31
# 37.7790262 -122.4199061
# 32
# ...

# %%
longitude=[]
latitude=[]
for place in first_file:
    latitude.append(place.latitude)
    longitude.append(place.longitude)

# %%
df['latitude']=latitude
df['longitude']=longitude

# %%
geometry = [Point(xy) for xy in zip(df['longitude'],df['latitude'])]
geometry[:7]

# %%
crs = {'init': 'epsg:4326'}

## convert df to geo df
geo_df = gpd.GeoDataFrame(df, crs=crs, geometry=geometry)
geo_df.head()
# Out:
# C:\Users\nishant\anaconda3\envs\hacker\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
#     user_id         username  age          status sex orientation    drinks  \
# 0  fffe3100      Edith Lopez   27          single   f         gay  socially
# 1  fffe3200     Travis Young   26          single   m         gay  socially
# 2  fffe3300      Agnes Smith   20  seeing someone   f    bisexual  socially
# 3  fffe3400  Salvador Klaver   27          single   m    bisexual  socially
# 4  fffe3500     Elana Sewell   22          single   f    bisexual     often
#
#        drugs  height                             job  ... body_profile  \
# ...

# %%
countries_map =gpd.read_file('C:/Users/nishant/HackerEarth Competition/Longitude_Graticules_and_World_Countries_Boundaries-shp/99bfd9e7-bb42-4728-87b5-07f8c8ac631c2020328-1-1vef4ev.lu5nk.shp')
f, ax = plt.subplots(figsize=(16, 16))
countries_map.plot(ax=ax, alpha=0.4, color='grey')
geo_df['geometry'].plot(ax=ax, markersize = 100, color = 'black', marker = 's', alpha=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The Following Map shows that the User of the Dating App are Mostly from North America and Parts Of Europe this also tells us that the Dating app does not have a user base in asia and africa .

# %%
t=geo_df.groupby('status').location.value_counts()
ls=dict()
for i in t.single.keys():
    ls[str_to_city(i)]=t.single[i]

# %%
lat_lon_single = []
for cit in ls.keys(): 
    
    try:
        location = geolocator.geocode(cit)
        
        if location:
            print(location.latitude, location.longitude)
            lat_lon_single.append(location)
    except GeocoderTimedOut as e:
        print(f"Error: geocode failed on input {cit} with message {e}")
# Out:
# 37.7790262 -122.4199061
# 37.8044557 -122.2713563
# 37.8708393 -122.2728639
# 37.496904 -122.3330573
# 37.4443293 -122.1598465
# 37.9735346 -122.5310874
# 37.6090291 -121.899142
# 37.7249296 -122.1560768
# 37.4863239 -122.232523
# 37.9020731 -122.0618702
# 37.6904826 -122.4726708
# 37.8314089 -122.2865266
# 37.6688205 -122.0807964
# 37.6138253 -122.4869194
# 37.5385087 -77.43428
# 38.049365 -122.1585777
# 37.5841026 -122.3660825
# -31.8546304 -52.8151659
# 37.4519671 -122.1779927
# 37.9060368 -122.5449763
# 37.3893889 -122.0832101
# 37.6535403 -122.4168664
# 38.1040864 -122.2566367
# 38.1061979 -122.5681191
# 37.9479786 -122.0607963
# 37.71573685 -122.09063177147789
# 38.0138934 -122.1338674
# 29.9978185 -83.2221527
# 48.4086571 7.2386756
# 37.504936 -122.2618236
# 37.9774476 -122.2949894
# 37.6261715 -122.4332435
# 37.5482697 -121.9885719
# 37.598958 -122.4009419
# 42.6511674 -73.754968
# 38.0171441 -122.2885808
# 42.3832108 9.287966
# -23.5506507 -46.6333824
# ...

# %%
new_df=pd.DataFrame(list(ls.items())) 

new_df['longitude']=[i.longitude for i in lat_lon_single]
new_df['latitude']=[i.latitude for i in lat_lon_single]

# %%
geometry = [Point(xy) for xy in zip(new_df['longitude'],new_df['latitude'])]

# %%
geo_df_single = gpd.GeoDataFrame(new_df, geometry=geometry)
f, ax = plt.subplots(figsize=(16, 16))
countries_map.plot(ax=ax, alpha=0.4, color='grey')
geo_df_single.plot(column='1',ax=ax, markersize =100 , color = 'red', marker = "o", alpha=0.2)
# Out:
# C:\Users\nishant\anaconda3\envs\hacker\lib\site-packages\geopandas\plotting.py:572: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(
# <AxesSubplot:>

# %% [markdown]
# The Number of Single Users are located in one location in the San Francisco city of USA and also the USA is the prime hub of the usage of this app for single status profiles.

# %%
geo_df_single
# Out:
#                  0    1   longitude   latitude                     geometry
# 0    san francisco  854 -122.419906  37.779026  POINT (-122.41991 37.77903)
# 1          oakland  235 -122.271356  37.804456  POINT (-122.27136 37.80446)
# 2         berkeley  131 -122.272864  37.870839  POINT (-122.27286 37.87084)
# 3        san mateo   54 -122.333057  37.496904  POINT (-122.33306 37.49690)
# 4        palo alto   40 -122.159847  37.444329  POINT (-122.15985 37.44433)
# ..             ...  ...         ...        ...                          ...
# 64        petaluma    1 -122.606122  38.270022  POINT (-122.60612 38.27002)
# 65         phoenix    1 -112.074142  33.448437  POINT (-112.07414 33.44844)
# 66  point richmond    1 -122.389138  37.924092  POINT (-122.38914 37.92409)
# 67      santa rosa    1  -90.350882  14.150152   POINT (-90.35088 14.15015)
# 68        stockton    1 -121.290780  37.957702  POINT (-121.29078 37.95770)
#
# [69 rows x 5 columns]

# %% [markdown]
# ## Bio

# %%
df['bio'][0]
# Out:
# "bottom line i love life! i work hard and i love hard! i'm down to earth... drama free and plan to keep it that way... if you want to know more about me just ask! i'm a woman with loves other women!. sometimes you feel like a nut sometimes you don't... i have a femme side and a butch side. i love trying new things. i spend my day helping people so i can check that off the list. i'm very out going and i love making people laugh! i'm open to meeting new people and dating. at this point i'm taking care of my heart and not rushing anything. i value communication and being open-minded."

# %%
from wordcloud import WordCloud, STOPWORDS 
comment_words = '' 
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in df.bio: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %% [markdown]
# Dating Bio Have these words majorly used words and love,friends, people,enjoy was expected which came out to be true.This feature is also important as the people firstly share there bio with others to get matched.
